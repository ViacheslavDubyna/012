# %%
pip install graphviz
# Out:
# ...
#
# ...

# %%
python context_diagram.py
# Out:
#   Cell In[1], line 1
#     python context_diagram.py
#            ^
# SyntaxError: invalid syntax

# %%
from graphviz import Digraph

# Створення об'єкту діаграми
dot = Digraph(comment='Контекстна діаграма A-0: Оперативне управління НГУ')
dot.attr(rankdir='LR')  # Орієнтація зліва направо

# Центральний процес
dot.node('A0', 'Здійснення оперативного управління НГУ', shape='box', style='filled', fillcolor='lightgrey')

# Входи (INPUTS)
inputs = {
    'input1': 'Директиви вищого рівня',
    'input2': 'Оперативна обстановка',
    'input3': 'Запити від підрозділів',
    'input4': 'Дані про ресурси',
    'input5': 'Цілі держполітики'
}
for key, label in inputs.items():
    dot.node(key, label, shape='ellipse', fillcolor='lightblue', style='filled')
    dot.edge(key, 'A0')

# Керування (CONTROLS)
controls = {
    'control1': 'Законодавство України',
    'control2': 'Військові статути',
    'control3': 'Стратегічні плани',
    'control4': 'Замисел командування',
    'control5': 'Правила ROE',
    'control6': 'Стандарти НАТО',
    'control7': 'Ресурсні обмеження'
}
for key, label in controls.items():
    dot.node(key, label, shape='diamond', fillcolor='lightyellow', style='filled')
    dot.edge(key, 'A0')

# Виходи (OUTPUTS)
outputs = {
    'output1': 'Управлінські рішення',
    'output2': 'Дії підрозділів НГУ',
    'output3': 'Звіти командуванню',
    'output4': 'Оперативна картина',
    'output5': 'Взаємодія',
    'output6': 'Розпорядження ресурсами'
}
for key, label in outputs.items():
    dot.node(key, label, shape='ellipse', fillcolor='lightgreen', style='filled')
    dot.edge('A0', key)

# Механізми (MECHANISMS)
mechanisms = {
    'mech1': 'Органи управління НГУ',
    'mech2': 'Пункти управління',
    'mech3': 'Система зв’язку',
    'mech4': 'Розвідка',
    'mech5': 'Логістика',
    'mech6': 'Особовий склад',
    'mech7': 'Нормативна база'
}
for key, label in mechanisms.items():
    dot.node(key, label, shape='component', fillcolor='lightpink', style='filled')
    dot.edge(key, 'A0', style='dashed')

# Налаштування стилю
dot.attr(label='Контекстна діаграма A-0: Оперативне управління НГУ\nДата: 07.04.2025')
dot.attr(fontsize='12')

# Збереження та відображення
dot.render('context_diagram_A0', format='png', cleanup=True)
print("Діаграма збережена як 'context_diagram_A0.png'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# ...

# %%
try:
    from graphviz import Digraph
except ImportError:
    print("Помилка: Встановіть graphviz командою: pip install graphviz")
    raise

try:
    # ... existing code ...

    # Налаштування стилю
    dot.attr(label='Контекстна діаграма A-0: Оперативне управління НГУ\nДата: 07.04.2025')
    dot.attr(fontsize='12')

    # Збереження та відображення з повним шляхом
    output_path = r'd:\Work ub\012\Practice 4.3\practice 5\context_diagram_A0'
    dot.render(output_path, format='png', cleanup=True)
    print(f"Діаграма успішно збережена як '{output_path}.png'")

except FileNotFoundError:
    print("Помилка: Неможливо зберегти файл. Перевірте права доступу до директорії.")
except Exception as e:
    print(f"Помилка при створенні діаграми: {str(e)}")
    print("\nПеревірте:")
    print("1. Чи встановлено Graphviz з сайту https://graphviz.org/download/")
    print("2. Чи є доступ до вказаної директорії")
# Out:
# Помилка при створенні діаграми: name 'dot' is not defined
#
# Перевірте:
# 1. Чи встановлено Graphviz з сайту https://graphviz.org/download/
# 2. Чи є доступ до вказаної директорії

# %%
try:
    from graphviz import Digraph
except ImportError:
    print("Помилка: Встановіть graphviz командою: pip install graphviz")
    raise

try:
    # Створення об'єкту діаграми
    dot = Digraph(comment='Контекстна діаграма A-0: Оперативне управління НГУ')
    dot.attr(rankdir='LR')  # Орієнтація зліва направо

    # Центральний процес
    dot.node('A0', 'Здійснення оперативного управління НГУ', shape='box', style='filled', fillcolor='lightgrey')

    # Входи (INPUTS)
    inputs = {
        'input1': 'Директиви вищого рівня',
        'input2': 'Оперативна обстановка',
        'input3': 'Запити від підрозділів',
        'input4': 'Дані про ресурси',
        'input5': 'Цілі держполітики'
    }
    for key, label in inputs.items():
        dot.node(key, label, shape='ellipse', fillcolor='lightblue', style='filled')
        dot.edge(key, 'A0')

    # Керування (CONTROLS)
    controls = {
        'control1': 'Законодавство України',
        'control2': 'Військові статути',
        'control3': 'Стратегічні плани',
        'control4': 'Замисел командування',
        'control5': 'Правила ROE',
        'control6': 'Стандарти НАТО',
        'control7': 'Ресурсні обмеження'
    }
    for key, label in controls.items():
        dot.node(key, label, shape='diamond', fillcolor='lightyellow', style='filled')
        dot.edge(key, 'A0')

    # Виходи (OUTPUTS)
    outputs = {
        'output1': 'Управлінські рішення',
        'output2': 'Дії підрозділів НГУ',
        'output3': 'Звіти командуванню',
        'output4': 'Оперативна картина',
        'output5': 'Взаємодія',
        'output6': 'Розпорядження ресурсами'
    }
    for key, label in outputs.items():
        dot.node(key, label, shape='ellipse', fillcolor='lightgreen', style='filled')
        dot.edge('A0', key)

    # Механізми (MECHANISMS)
    mechanisms = {
        'mech1': 'Органи управління НГУ',
        'mech2': 'Пункти управління',
        'mech3': 'Система зв'язку',
        'mech4': 'Розвідка',
        'mech5': 'Логістика',
        'mech6': 'Особовий склад',
        'mech7': 'Нормативна база'
    }
    for key, label in mechanisms.items():
        dot.node(key, label, shape='component', fillcolor='lightpink', style='filled')
        dot.edge(key, 'A0', style='dashed')

    # Налаштування стилю
    dot.attr(label='Контекстна діаграма A-0: Оперативне управління НГУ\nДата: 07.04.2025')
    dot.attr(fontsize='12')

    # Збереження та відображення з повним шляхом
    output_path = r'd:\Work ub\012\Practice 4.3\practice 5\context_diagram_A0'
    dot.render(output_path, format='png', cleanup=True)
    print(f"Діаграма успішно збережена як '{output_path}.png'")

except FileNotFoundError:
    print("Помилка: Неможливо зберегти файл. Перевірте права доступу до директорії.")
except Exception as e:
    print(f"Помилка при створенні діаграми: {str(e)}")
    print("\nПеревірте:")
    print("1. Чи встановлено Graphviz з сайту https://graphviz.org/download/")
    print("2. Чи є доступ до вказаної директорії")
# Out:
#   Cell In[2], line 58
#     'mech3': 'Система зв'язку',
#                              ^
# SyntaxError: unterminated string literal (detected at line 58)

# %%
    # ... existing code ...
    
    # Механізми (MECHANISMS)
    mechanisms = {
        'mech1': 'Органи управління НГУ',
        'mech2': 'Пункти управління',
        'mech3': "Система зв'язку",  # Changed single quotes to double quotes
        'mech4': 'Розвідка',
        'mech5': 'Логістика',
        'mech6': 'Особовий склад',
        'mech7': 'Нормативна база'
    }
    
    # ... rest of the code ...

# %%
try:
    from graphviz import Digraph
except ImportError:
    print("Помилка: Встановіть graphviz командою: pip install graphviz")
    raise

try:
    # Створення об'єкту діаграми
    dot = Digraph(comment='Контекстна діаграма A-0: Оперативне управління НГУ')
    dot.attr(rankdir='LR')  # Орієнтація зліва направо

    # Центральний процес
    dot.node('A0', 'Здійснення оперативного управління НГУ', shape='box', style='filled', fillcolor='lightgrey')

    # Входи (INPUTS)
    inputs = {
        'input1': 'Директиви вищого рівня',
        'input2': 'Оперативна обстановка',
        'input3': 'Запити від підрозділів',
        'input4': 'Дані про ресурси',
        'input5': 'Цілі держполітики'
    }
    for key, label in inputs.items():
        dot.node(key, label, shape='ellipse', fillcolor='lightblue', style='filled')
        dot.edge(key, 'A0')

    # Керування (CONTROLS)
    controls = {
        'control1': 'Законодавство України',
        'control2': 'Військові статути',
        'control3': 'Стратегічні плани',
        'control4': 'Замисел командування',
        'control5': 'Правила ROE',
        'control6': 'Стандарти НАТО',
        'control7': 'Ресурсні обмеження'
    }
    for key, label in controls.items():
        dot.node(key, label, shape='diamond', fillcolor='lightyellow', style='filled')
        dot.edge(key, 'A0')

    # Виходи (OUTPUTS)
    outputs = {
        'output1': 'Управлінські рішення',
        'output2': 'Дії підрозділів НГУ',
        'output3': 'Звіти командуванню',
        'output4': 'Оперативна картина',
        'output5': 'Взаємодія',
        'output6': 'Розпорядження ресурсами'
    }
    for key, label in outputs.items():
        dot.node(key, label, shape='ellipse', fillcolor='lightgreen', style='filled')
        dot.edge('A0', key)

    # Механізми (MECHANISMS)
    mechanisms = {
        'mech1': 'Органи управління НГУ',
        'mech2': 'Пункти управління',
        'mech3': "Система зв'язку",
        'mech4': 'Розвідка',
        'mech5': 'Логістика',
        'mech6': 'Особовий склад',
        'mech7': 'Нормативна база'
    }
    for key, label in mechanisms.items():
        dot.node(key, label, shape='component', fillcolor='lightpink', style='filled')
        dot.edge(key, 'A0', style='dashed')

    # Налаштування стилю
    dot.attr(label='Контекстна діаграма A-0: Оперативне управління НГУ\nДата: 07.04.2025')
    dot.attr(fontsize='12')

    # Перевірка доступу до директорії
    import os
    output_dir = r'd:\Work ub\012\Practice 4.3\practice 5'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Збереження та відображення з повним шляхом
    output_path = os.path.join(output_dir, 'context_diagram_A0')
    dot.render(output_path, format='png', cleanup=True)
    print(f"Діаграма успішно збережена як '{output_path}.png'")

except FileNotFoundError:
    print("Помилка: Неможливо зберегти файл. Перевірте права доступу до директорії.")
except Exception as e:
    print(f"Помилка при створенні діаграми: {str(e)}")
    print("\nПеревірте:")
    print("1. Чи встановлено Graphviz з сайту https://graphviz.org/download/")
    print("2. Чи є доступ до вказаної директорії")
# Out:
# Помилка при створенні діаграми: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH
#
# Перевірте:
# 1. Чи встановлено Graphviz з сайту https://graphviz.org/download/
# 2. Чи є доступ до вказаної директорії

# %%
import os

test_dir = r'd:\Work ub\012\Practice 4.3\practice 5'
try:
    # Перевірка існування директорії
    if not os.path.exists(test_dir):
        print(f"Директорія не існує: {test_dir}")
    
    # Перевірка прав на запис
    test_file = os.path.join(test_dir, 'test.txt')
    with open(test_file, 'w') as f:
        f.write('test')
    os.remove(test_file)
    print("Доступ до директорії в порядку")
except Exception as e:
    print(f"Проблема з доступом до директорії: {str(e)}")
# Out:
# Доступ до директорії в порядку

# %%
import os
import sys

def check_system():
    test_dir = r'd:\Work ub\012\Practice 4.3\practice 5'
    try:
        # Check Python version
        print(f"Python version: {sys.version}")
        
        # Check directory existence
        if not os.path.exists(test_dir):
            print(f"Directory doesn't exist: {test_dir}")
            try:
                os.makedirs(test_dir)
                print("Directory created successfully")
            except Exception as e:
                print(f"Cannot create directory: {e}")
                return False
        else:
            print("Directory exists")
        
        # Check write permissions
        test_file = os.path.join(test_dir, 'test.txt')
        try:
            with open(test_file, 'w') as f:
                f.write('test')
            print("Write test: Success")
            
            # Check read permissions
            with open(test_file, 'r') as f:
                content = f.read()
            print("Read test: Success")
            
            # Clean up
            os.remove(test_file)
            print("Delete test: Success")
            
            return True
        except Exception as e:
            print(f"File operation failed: {e}")
            return False
            
    except Exception as e:
        print(f"System check failed: {e}")
        return False

# Run the check
if check_system():
    print("\nAll system checks passed ✅")
else:
    print("\nSystem check failed ❌")
# Out:
# Python version: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Directory exists
# Write test: Success
# Read test: Success
# Delete test: Success
#
# All system checks passed ✅

# %%
import os
import sys
import subprocess

def перевірка_системи():
    тест_директорія = r'd:\Work ub\012\Practice 4.3\practice 5'
    try:
        # Перевірка версії Python
        print(f"Версія Python: {sys.version}")
        
        # Перевірка Graphviz
        try:
            результат = subprocess.run(['dot', '-V'], capture_output=True, text=True)
            print(f"Graphviz встановлено: {результат.stdout}")
        except FileNotFoundError:
            print("Помилка: Graphviz не знайдено! Встановіть його з https://graphviz.org/download/")
            return False
        
        # ... існуючий код перевірки директорії та файлів ...
        
        return True
    except Exception as e:
        print(f"Помилка перевірки системи: {e}")
        return False

# Запуск перевірки
if перевірка_системи():
    print("\nВсі перевірки пройдено успішно ✅")
else:
    print("\nПеревірка системи не вдалася ❌")
# Out:
# Версія Python: 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Помилка: Graphviz не знайдено! Встановіть його з https://graphviz.org/download/
#
# Перевірка системи не вдалася ❌

# %%
# %pip install networkx matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 13.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Створення графа
G = nx.DiGraph()

# Додавання вузлів та ребер
G.add_node("Здійснення оперативного управління НГУ", style='filled', fillcolor='lightgrey')

# Входи (INPUTS)
inputs = ["Директиви вищого рівня", "Оперативна обстановка", "Запити від підрозділів", 
          "Дані про ресурси", "Цілі держполітики"]
for i in inputs:
    G.add_node(i, style='filled', fillcolor='lightblue')
    G.add_edge(i, "Здійснення оперативного управління НГУ")

# Керування (CONTROLS)
controls = ["Законодавство України", "Військові статути", "Стратегічні плани", 
            "Замисел командування", "Правила ROE", "Стандарти НАТО", "Ресурсні обмеження"]
for c in controls:
    G.add_node(c, style='filled', fillcolor='lightyellow')
    G.add_edge(c, "Здійснення оперативного управління НГУ")

# Виходи (OUTPUTS)
outputs = ["Управлінські рішення", "Дії підрозділів НГУ", "Звіти командуванню", 
           "Оперативна картина", "Взаємодія", "Розпорядження ресурсами"]
for o in outputs:
    G.add_node(o, style='filled', fillcolor='lightgreen')
    G.add_edge("Здійснення оперативного управління НГУ", o)

# Механізми (MECHANISMS)
mechanisms = ["Органи управління НГУ", "Пункти управління", "Система зв'язку", 
              "Розвідка", "Логістика", "Особовий склад", "Нормативна база"]
for m in mechanisms:
    G.add_node(m, style='filled', fillcolor='lightpink')
    G.add_edge(m, "Здійснення оперативного управління НГУ", style='dashed')

# Візуалізація
pos = nx.spring_layout(G, seed=42)  # Розташування вузлів
nx.draw(G, pos, with_labels=True, node_size=2000, node_color='skyblue', font_size=8)
plt.title("Контекстна діаграма A-0: Оперативне управління НГУ")
plt.show()

# %%
# %pip install --upgrade graphviz

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Створення графа
G = nx.DiGraph()

# Додавання вузлів та ребер
G.add_node("Здійснення оперативного управління НГУ", style='filled', fillcolor='lightgrey')

# Входи (INPUTS)
inputs = ["Директиви вищого рівня", "Оперативна обстановка", "Запити від підрозділів", 
          "Дані про ресурси", "Цілі держполітики"]
for i in inputs:
    G.add_node(i, style='filled', fillcolor='lightblue')
    G.add_edge(i, "Здійснення оперативного управління НГУ")

# Керування (CONTROLS)
controls = ["Законодавство України", "Військові статути", "Стратегічні плани", 
            "Замисел командування", "Правила ROE", "Стандарти НАТО", "Ресурсні обмеження"]
for c in controls:
    G.add_node(c, style='filled', fillcolor='lightyellow')
    G.add_edge(c, "Здійснення оперативного управління НГУ")

# Виходи (OUTPUTS)
outputs = ["Управлінські рішення", "Дії підрозділів НГУ", "Звіти командуванню", 
           "Оперативна картина", "Взаємодія", "Розпорядження ресурсами"]
for o in outputs:
    G.add_node(o, style='filled', fillcolor='lightgreen')
    G.add_edge("Здійснення оперативного управління НГУ", o)

# Механізми (MECHANISMS)
mechanisms = ["Органи управління НГУ", "Пункти управління", "Система зв'язку", 
              "Розвідка", "Логістика", "Особовий склад", "Нормативна база"]
for m in mechanisms:
    G.add_node(m, style='filled', fillcolor='lightpink')
    G.add_edge(m, "Здійснення оперативного управління НГУ", style='dashed')

# Візуалізація
pos = nx.spring_layout(G, seed=42)  # Розташування вузлів
nx.draw(G, pos, with_labels=True, node_size=2000, node_color='skyblue', font_size=8)
plt.title("Контекстна діаграма A-0: Оперативне управління НГУ")
plt.show()

# %%
from graphviz import Digraph

# Створення об'єкту діаграми
dot = Digraph(comment='Контекстна діаграма A-0: Оперативне управління НГУ')
dot.attr(rankdir='LR', fontsize='12')
dot.attr(label='Контекстна діаграма A-0: Оперативне управління НГУ\nДата: 07.04.2025')

# Центральний процес
dot.node('A0', 'Здійснення оперативного управління НГУ', 
        shape='box', style='filled', fillcolor='lightgrey')

# Входи (INPUTS)
inputs = [
    'Директиви вищого рівня',
    'Оперативна обстановка',
    'Запити від підрозділів',
    'Дані про ресурси',
    'Цілі держполітики'
]
for i, label in enumerate(inputs, 1):
    dot.node(f'input{i}', label, shape='ellipse', style='filled', fillcolor='lightblue')
    dot.edge(f'input{i}', 'A0')

# Керування (CONTROLS)
controls = [
    'Законодавство України',
    'Військові статути',
    'Стратегічні плани',
    'Замисел командування',
    'Правила ROE',
    'Стандарти НАТО',
    'Ресурсні обмеження'
]
for i, label in enumerate(controls, 1):
    dot.node(f'control{i}', label, shape='diamond', style='filled', fillcolor='lightyellow')
    dot.edge(f'control{i}', 'A0')

# Виходи (OUTPUTS)
outputs = [
    'Управлінські рішення',
    'Дії підрозділів НГУ',
    'Звіти командуванню',
    'Оперативна картина',
    'Взаємодія',
    'Розпорядження ресурсами'
]
for i, label in enumerate(outputs, 1):
    dot.node(f'output{i}', label, shape='ellipse', style='filled', fillcolor='lightgreen')
    dot.edge('A0', f'output{i}')

# Механізми (MECHANISMS)
mechanisms = [
    'Органи управління НГУ',
    'Пункти управління',
    "Система зв'язку",
    'Розвідка',
    'Логістика',
    'Особовий склад',
    'Нормативна база'
]
for i, label in enumerate(mechanisms, 1):
    dot.node(f'mech{i}', label, shape='component', style='filled', fillcolor='lightpink')
    dot.edge(f'mech{i}', 'A0', style='dashed')

# Збереження діаграми
dot.render('context_diagram_A0', format='png', cleanup=True)
print("Діаграма збережена як 'context_diagram_A0.png'")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# ...

# %%
import subprocess
import sys
import os

def перевірка_та_встановлення():
    try:
        # Перевірка pip
        subprocess.run([sys.executable, '-m', 'pip', 'install', 'graphviz'], check=True)
        print("✅ Пакет graphviz встановлено")
        
        # Перевірка Graphviz
        try:
            результат = subprocess.run(['dot', '-V'], capture_output=True, text=True)
            print(f"✅ Graphviz встановлено: {результат.stdout.strip()}")
        except FileNotFoundError:
            print("❌ Graphviz не знайдено!")
            print("🔄 Встановлюю Graphviz...")
            subprocess.run(['winget', 'install', 'graphviz'], check=True)
            print("✅ Graphviz встановлено")
            print("⚠️ Потрібно перезавантажити комп'ютер")
            return False
        
        return True
    except Exception as e:
        print(f"❌ Помилка: {e}")
        return False

def створити_діаграму():
    from graphviz import Digraph
    
    # Ваш існуючий код для створення діаграми
    # ... (весь код залишається без змін)
    
    # Змінюємо шлях збереження на абсолютний
    output_path = r'd:\Work ub\012\Practice 4.3\practice 5\context_diagram_A0'
    dot.render(output_path, format='png', cleanup=True)
    print(f"✅ Діаграма збережена як '{output_path}.png'")

def main():
    if перевірка_та_встановлення():
        створити_діаграму()
    else:
        print("\n⚠️ Спочатку перезавантажте комп'ютер і запустіть код знову")

if __name__ == "__main__":
    main()
# Out:
# ✅ Пакет graphviz встановлено
# ❌ Graphviz не знайдено!
# 🔄 Встановлюю Graphviz...
